# %%
import pandas as pd

# %%
exchanges = pd.read_csv("/proj/gibbons/sswegle_micom/Res_Saves/exchanges_swegle.csv")

# %% [markdown]
# now I will select exchanges for only one taxa

# %%
Prevotella = exchanges[exchanges.taxon == "Prevotella"]
Prevotella
# Out:
#         Unnamed: 0       taxon    sample_id  tolerance           reaction  \
# 6409         23085  Prevotella  SRR15032095   0.000001            EX_h(e)
# 6410         23092  Prevotella  SRR15032095   0.000001         EX_malt(e)
# 6411         23093  Prevotella  SRR15032095   0.000001           EX_pi(e)
# 6412         23094  Prevotella  SRR15032095   0.000001        EX_acnam(e)
# 6413         23100  Prevotella  SRR15032095   0.000001          EX_gly(e)
# ...            ...         ...          ...        ...                ...
# 490766     2504824  Prevotella  SRR15032510   0.000001         EX_succ(e)
# 490767     2504826  Prevotella  SRR15032510   0.000001  EX_MGlcn171_rl(e)
# 490768     2504827  Prevotella  SRR15032510   0.000001   EX_gncore1_rl(e)
# 490769     2504828  Prevotella  SRR15032510   0.000001      EX_MGlcn14(e)
# 490770     2504829  Prevotella  SRR15032510   0.000001   EX_MGlcn40_rl(e)
#
#              flux  abundance      metabolite direction
# 6409   -97.331225   0.215981            h[e]    import
# 6410    -0.027801   0.215981         malt[e]    import
# 6411   -64.707708   0.215981           pi[e]    import
# 6412    -5.268732   0.215981        acnam[e]    import
# 6413    15.048312   0.215981          gly[e]    export
# ...           ...        ...             ...       ...
# 490766 -53.906947   0.022368         succ[e]    import
# 490767   0.000007   0.022368  MGlcn171_rl[e]    export
# 490768   0.000002   0.022368   gncore1_rl[e]    export
# 490769   0.000002   0.022368      MGlcn14[e]    export
# 490770  -0.000003   0.022368   MGlcn40_rl[e]    import
#
# [12311 rows x 9 columns]

# %% [markdown]
# add metadata for the labels

# %%
metadata = pd.read_csv("/proj/gibbons/sswegle_micom/All the Steps/metadata_swegle.csv")
metadata
# Out:
#      Unnamed: 0    sample_id               description  time_point  \
# 0             0  SRR15032078           High fiber diet           8
# 1             1  SRR15032079           High fiber diet           4
# 2             2  SRR15032080  High fermented food diet           3
# 3             3  SRR15032081  High fermented food diet           2
# 4             4  SRR15032082           High fiber diet           7
# ..          ...          ...                       ...         ...
# 306         306  SRR15032510  High fermented food diet           2
# 307         307  SRR15032511           High fiber diet           6
# 308         308  SRR15032512  High fermented food diet           7
# 309         309  SRR15032513  High fermented food diet           6
# 310         310  SRR15032514           High fiber diet           9
#
#                    file  found_taxa  total_taxa  found_fraction  \
# 0    SRR15032078.pickle        24.0        37.0        0.648649
# 1    SRR15032079.pickle        21.0        25.0        0.840000
# 2    SRR15032080.pickle        16.0        27.0        0.592593
# 3    SRR15032081.pickle        11.0        17.0        0.647059
# 4    SRR15032082.pickle        23.0        33.0        0.696970
# ..                  ...         ...         ...             ...
# 306  SRR15032510.pickle        21.0        28.0        0.750000
# 307  SRR15032511.pickle        22.0        32.0        0.687500
# 308  SRR15032512.pickle        23.0        37.0        0.621622
# 309  SRR15032513.pickle        19.0        30.0        0.633333
# 310  SRR15032514.pickle        24.0        37.0        0.648649
#
#      found_abundance_fraction      medium
# 0                    0.889586  high_fiber
# 1                    0.942212  high_fiber
# 2                    0.855661   fermented
# 3                    0.898909     western
# 4                    0.908204  high_fiber
# ..                        ...         ...
# 306                  0.881483     western
# 307                  0.799526  high_fiber
# 308                  0.843232   fermented
# 309                  0.839063   fermented
# 310                  0.740106     western
#
# [311 rows x 10 columns]

# %%
filtered_meta = metadata[metadata.time_point < 8]

# %%
merged = Prevotella.merge(filtered_meta, on="sample_id")
merged
# Out:
#       Unnamed: 0_x       taxon    sample_id  tolerance           reaction  \
# 0            23085  Prevotella  SRR15032095   0.000001            EX_h(e)
# 1            23092  Prevotella  SRR15032095   0.000001         EX_malt(e)
# 2            23093  Prevotella  SRR15032095   0.000001           EX_pi(e)
# 3            23094  Prevotella  SRR15032095   0.000001        EX_acnam(e)
# 4            23100  Prevotella  SRR15032095   0.000001          EX_gly(e)
# ...            ...         ...          ...        ...                ...
# 9019       2504824  Prevotella  SRR15032510   0.000001         EX_succ(e)
# 9020       2504826  Prevotella  SRR15032510   0.000001  EX_MGlcn171_rl(e)
# 9021       2504827  Prevotella  SRR15032510   0.000001   EX_gncore1_rl(e)
# 9022       2504828  Prevotella  SRR15032510   0.000001      EX_MGlcn14(e)
# 9023       2504829  Prevotella  SRR15032510   0.000001   EX_MGlcn40_rl(e)
#
#            flux  abundance      metabolite direction  Unnamed: 0_y  \
# 0    -97.331225   0.215981            h[e]    import            17
# 1     -0.027801   0.215981         malt[e]    import            17
# 2    -64.707708   0.215981           pi[e]    import            17
# 3     -5.268732   0.215981        acnam[e]    import            17
# 4     15.048312   0.215981          gly[e]    export            17
# ...         ...        ...             ...       ...           ...
# 9019 -53.906947   0.022368         succ[e]    import           306
# 9020   0.000007   0.022368  MGlcn171_rl[e]    export           306
# 9021   0.000002   0.022368   gncore1_rl[e]    export           306
# 9022   0.000002   0.022368      MGlcn14[e]    export           306
# 9023  -0.000003   0.022368   MGlcn40_rl[e]    import           306
#
#                    description  time_point                file  found_taxa  \
# 0              High fiber diet           6  SRR15032095.pickle        17.0
# 1              High fiber diet           6  SRR15032095.pickle        17.0
# 2              High fiber diet           6  SRR15032095.pickle        17.0
# 3              High fiber diet           6  SRR15032095.pickle        17.0
# 4              High fiber diet           6  SRR15032095.pickle        17.0
# ...                        ...         ...                 ...         ...
# 9019  High fermented food diet           2  SRR15032510.pickle        21.0
# 9020  High fermented food diet           2  SRR15032510.pickle        21.0
# 9021  High fermented food diet           2  SRR15032510.pickle        21.0
# 9022  High fermented food diet           2  SRR15032510.pickle        21.0
# 9023  High fermented food diet           2  SRR15032510.pickle        21.0
#
#       total_taxa  found_fraction  found_abundance_fraction      medium
# 0           21.0        0.809524                  0.931123  high_fiber
# 1           21.0        0.809524                  0.931123  high_fiber
# 2           21.0        0.809524                  0.931123  high_fiber
# 3           21.0        0.809524                  0.931123  high_fiber
# 4           21.0        0.809524                  0.931123  high_fiber
# ...          ...             ...                       ...         ...
# 9019        28.0        0.750000                  0.881483     western
# 9020        28.0        0.750000                  0.881483     western
# 9021        28.0        0.750000                  0.881483     western
# 9022        28.0        0.750000                  0.881483     western
# 9023        28.0        0.750000                  0.881483     western
#
# [9024 rows x 18 columns]

# %%
annotations = pd.read_csv("/proj/gibbons/sswegle_micom/Res_Saves/annotations_swegle.csv")

# %%
merged_with_annotations = merged.merge(annotations, on="metabolite")

# %%
merged_with_annotations.columns
# Out:
# Index(['Unnamed: 0_x', 'taxon', 'sample_id', 'tolerance', 'reaction_x', 'flux',
#        'abundance', 'metabolite', 'direction', 'Unnamed: 0_y', 'description',
#        'time_point', 'file', 'found_taxa', 'total_taxa', 'found_fraction',
#        'found_abundance_fraction', 'medium', 'reaction_y', 'name',
#        'molecular_weight', 'C_number', 'N_number', 'hmdb', 'inchi',
#        'kegg.compound', 'pubchem.compound', 'reaction.1'],
#       dtype='object')

# %%
import pandas as pd

imports = pd.pivot_table(
    merged_with_annotations[merged_with_annotations.direction == "import"], 
    index="name", 
    columns="sample_id", 
    values="flux",
    fill_value=0  # if the reactions is absent in a sample there is no flux
)

imports.head()
# Out:
# sample_id         SRR15032079  SRR15032083  SRR15032087  SRR15032092  \
# name
# (R)-Pantothenate     0.000000     0.000000     0.000000     0.000000
# (R)-lactate          0.000000   -35.632375     0.000000     0.000000
# (S)-lactate          0.000000   -35.821652     0.000000     0.000000
# (S)-malate(2-)       0.000000   -70.165340   -30.318669   -50.660148
# 2-Oxobutanoate     -96.315752   -85.456374   -95.251462   -96.096792
#
# sample_id         SRR15032094  SRR15032095  SRR15032096  SRR15032103  \
# name
# (R)-Pantothenate     0.000000     0.000000     0.000000     0.000000
# (R)-lactate          0.000000     0.000000     0.000000   -17.681183
# (S)-lactate          0.000000     0.000000     0.000000     0.000000
# (S)-malate(2-)     -39.296585    -3.595775   -35.085640   -23.427508
# 2-Oxobutanoate     -96.452429   -97.178458   -93.649651   -95.180926
#
# sample_id         SRR15032108  SRR15032109  ...  SRR15032449  SRR15032450  \
# name                                        ...
# (R)-Pantothenate     0.000000    -0.000259  ...     0.000000     0.000000
# (R)-lactate          0.000000     0.000000  ...     0.000000     0.000000
# (S)-lactate          0.000000     0.000000  ...     0.000000     0.000000
# (S)-malate(2-)     -45.746246   -51.436974  ...   -53.086763   -32.514195
# 2-Oxobutanoate     -94.705061   -95.798799  ...   -97.082411   -94.279706
#
# sample_id         SRR15032453  SRR15032485  SRR15032487  SRR15032493  \
# name
# (R)-Pantothenate     0.000000     0.000000     0.000000     0.000000
# (R)-lactate        -40.633408     0.000000     0.000000     0.000000
# (S)-lactate        -40.716894     0.000000     0.000000     0.000000
# (S)-malate(2-)     -67.783298   -58.626274     0.000000   -48.522906
# 2-Oxobutanoate     -85.434325   -86.389571   -94.918512   -88.866988
#
# sample_id         SRR15032495  SRR15032502  SRR15032505  SRR15032510
# name
# (R)-Pantothenate     0.000000     0.000000     0.000000    -0.000337
# (R)-lactate         -0.107810     0.000000     0.000000     0.000000
# (S)-lactate          0.000000     0.000000     0.000000     0.000000
# (S)-malate(2-)     -40.190370   -70.018554     0.000000   -41.956495
# 2-Oxobutanoate     -87.761565   -97.024848   -66.099114   -91.857611
#
# [5 rows x 81 columns]

# %%
import seaborn as sns
import numpy as np

label_map = pd.Series({"high_fiber": "tomato", "fermented": "pink", "western": "seagreen"})
labels = merged_with_annotations[["sample_id", "medium"]].drop_duplicates().set_index("sample_id")
labels["status"] = label_map[labels.medium].values

test_heat_map = sns.clustermap(
    np.log10(-imports + 1e-6), # Convert to positive fluxes and log-transform
    figsize=(12, 24),           # we have way more reactions than samples here
    col_colors=labels.status   # must be a series with one color for each sample ID 
)

#test_heat_map.savefig("testing_saving_heatmaps.png")
# Out:
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/seaborn/matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
imports
# Out:
# sample_id                                          SRR15032079  SRR15032083  \
# name
# (R)-Pantothenate                                      0.000000     0.000000
# (R)-lactate                                           0.000000   -35.632375
# (S)-lactate                                           0.000000   -35.821652
# (S)-malate(2-)                                        0.000000   -70.165340
# 2-Oxobutanoate                                      -96.315752   -85.456374
# ...                                                        ...          ...
# starch, structure 2 (1,6-{2[1,4-Glc], [1,4-Glc]})     0.000000     0.000000
# sulfate                                              -0.014586    -0.387464
# tetradecanoate (n-C14:0)                              0.000000   -19.285590
# thiosulfate(2-)                                       0.000000     0.000000
# uracil                                              -94.125012   -52.747594
#
# sample_id                                          SRR15032087  SRR15032092  \
# name
# (R)-Pantothenate                                      0.000000     0.000000
# (R)-lactate                                           0.000000     0.000000
# (S)-lactate                                           0.000000     0.000000
# (S)-malate(2-)                                      -30.318669   -50.660148
# 2-Oxobutanoate                                      -95.251462   -96.096792
# ...                                                        ...          ...
# starch, structure 2 (1,6-{2[1,4-Glc], [1,4-Glc]})     0.000000     0.000000
# sulfate                                              -3.446093    -0.150393
# tetradecanoate (n-C14:0)                              0.000000     0.000000
# thiosulfate(2-)                                       0.000000    -0.073808
# uracil                                              -79.256802   -67.550434
#
# sample_id                                          SRR15032094  SRR15032095  \
# name
# (R)-Pantothenate                                      0.000000     0.000000
# (R)-lactate                                           0.000000     0.000000
# (S)-lactate                                           0.000000     0.000000
# (S)-malate(2-)                                      -39.296585    -3.595775
# 2-Oxobutanoate                                      -96.452429   -97.178458
# ...                                                        ...          ...
# starch, structure 2 (1,6-{2[1,4-Glc], [1,4-Glc]})     0.000000     0.000000
# sulfate                                              -0.004472    -0.013138
# tetradecanoate (n-C14:0)                              0.000000     0.000000
# thiosulfate(2-)                                       0.000000    -0.005538
# uracil                                              -95.084946   -95.394480
#
# sample_id                                          SRR15032096  SRR15032103  \
# name
# (R)-Pantothenate                                      0.000000     0.000000
# (R)-lactate                                           0.000000   -17.681183
# (S)-lactate                                           0.000000     0.000000
# (S)-malate(2-)                                      -35.085640   -23.427508
# 2-Oxobutanoate                                      -93.649651   -95.180926
# ...                                                        ...          ...
# starch, structure 2 (1,6-{2[1,4-Glc], [1,4-Glc]})     0.000000     0.000000
# sulfate                                              -4.120863    -0.004055
# tetradecanoate (n-C14:0)                              0.000000     0.000000
# thiosulfate(2-)                                       0.000000     0.000000
# uracil                                              -61.693913   -95.490711
#
# sample_id                                          SRR15032108  SRR15032109  \
# name
# (R)-Pantothenate                                      0.000000    -0.000259
# (R)-lactate                                           0.000000     0.000000
# (S)-lactate                                           0.000000     0.000000
# (S)-malate(2-)                                      -45.746246   -51.436974
# 2-Oxobutanoate                                      -94.705061   -95.798799
# ...                                                        ...          ...
# starch, structure 2 (1,6-{2[1,4-Glc], [1,4-Glc]})     0.000000     0.000000
# sulfate                                              -0.011515    -0.398367
# tetradecanoate (n-C14:0)                              0.000000     0.000000
# thiosulfate(2-)                                       0.000000    -0.156040
# uracil                                              -67.096431   -64.058216
#
# sample_id                                          ...  SRR15032449  \
# name                                               ...
# (R)-Pantothenate                                   ...     0.000000
# (R)-lactate                                        ...     0.000000
# (S)-lactate                                        ...     0.000000
# (S)-malate(2-)                                     ...   -53.086763
# 2-Oxobutanoate                                     ...   -97.082411
# ...                                                ...          ...
# starch, structure 2 (1,6-{2[1,4-Glc], [1,4-Glc]})  ...     0.000000
# sulfate                                            ...    -0.593319
# tetradecanoate (n-C14:0)                           ...     0.000000
# thiosulfate(2-)                                    ...    -0.122920
# uracil                                             ...   -96.170791
#
# sample_id                                          SRR15032450  SRR15032453  \
# name
# (R)-Pantothenate                                      0.000000     0.000000
# (R)-lactate                                           0.000000   -40.633408
# (S)-lactate                                           0.000000   -40.716894
# (S)-malate(2-)                                      -32.514195   -67.783298
# 2-Oxobutanoate                                      -94.279706   -85.434325
# ...                                                        ...          ...
# starch, structure 2 (1,6-{2[1,4-Glc], [1,4-Glc]})     0.000000     0.000000
# sulfate                                              -0.015326    -0.359531
# tetradecanoate (n-C14:0)                              0.000000   -15.657747
# thiosulfate(2-)                                      -0.008063    -0.191786
# uracil                                              -46.520552   -54.739350
#
# sample_id                                          SRR15032485  SRR15032487  \
# name
# (R)-Pantothenate                                      0.000000     0.000000
# (R)-lactate                                           0.000000     0.000000
# (S)-lactate                                           0.000000     0.000000
# (S)-malate(2-)                                      -58.626274     0.000000
# 2-Oxobutanoate                                      -86.389571   -94.918512
# ...                                                        ...          ...
# starch, structure 2 (1,6-{2[1,4-Glc], [1,4-Glc]})     0.000000     0.000000
# sulfate                                              -0.063474    -0.003069
# tetradecanoate (n-C14:0)                             -2.437416     0.000000
# thiosulfate(2-)                                      -0.033878     0.000000
# uracil                                              -49.624987   -93.011896
#
# sample_id                                          SRR15032493  SRR15032495  \
# name
# (R)-Pantothenate                                      0.000000     0.000000
# (R)-lactate                                           0.000000    -0.107810
# (S)-lactate                                           0.000000     0.000000
# (S)-malate(2-)                                      -48.522906   -40.190370
# 2-Oxobutanoate                                      -88.866988   -87.761565
# ...                                                        ...          ...
# starch, structure 2 (1,6-{2[1,4-Glc], [1,4-Glc]})     0.000000     0.000000
# sulfate                                              -0.031332   -15.785223
# tetradecanoate (n-C14:0)                             -0.843972     0.000000
# thiosulfate(2-)                                      -0.016619    -1.178937
# uracil                                              -49.585752   -55.756826
#
# sample_id                                          SRR15032502  SRR15032505  \
# name
# (R)-Pantothenate                                      0.000000     0.000000
# (R)-lactate                                           0.000000     0.000000
# (S)-lactate                                           0.000000     0.000000
# (S)-malate(2-)                                      -70.018554     0.000000
# 2-Oxobutanoate                                      -97.024848   -66.099114
# ...                                                        ...          ...
# starch, structure 2 (1,6-{2[1,4-Glc], [1,4-Glc]})     0.000000     0.000000
# sulfate                                              -0.557322    -0.141754
# tetradecanoate (n-C14:0)                              0.000000     0.000000
# thiosulfate(2-)                                      -0.031130     0.000000
# uracil                                              -87.228091   -60.522042
#
# sample_id                                          SRR15032510
# name
# (R)-Pantothenate                                     -0.000337
# (R)-lactate                                           0.000000
# (S)-lactate                                           0.000000
# (S)-malate(2-)                                      -41.956495
# 2-Oxobutanoate                                      -91.857611
# ...                                                        ...
# starch, structure 2 (1,6-{2[1,4-Glc], [1,4-Glc]})    -0.000002
# sulfate                                              -0.000182
# tetradecanoate (n-C14:0)                             -0.255658
# thiosulfate(2-)                                       0.000000
# uracil                                              -47.768122
#
# [328 rows x 81 columns]

# %%
import pandas as pd

imports = pd.pivot_table(
    merged_with_annotations[(merged_with_annotations.direction == "import") & (merged_with_annotations.flux < -1e-4)], 
    index="name", 
    columns="sample_id", 
    values="flux",
    fill_value=0  # if the reactions is absent in a sample there is no flux
)

imports.head()
# Out:
# sample_id         SRR15032079  SRR15032083  SRR15032087  SRR15032092  \
# name
# (R)-Pantothenate     0.000000     0.000000     0.000000     0.000000
# (R)-lactate          0.000000   -35.632375     0.000000     0.000000
# (S)-lactate          0.000000   -35.821652     0.000000     0.000000
# (S)-malate(2-)       0.000000   -70.165340   -30.318669   -50.660148
# 2-Oxobutanoate     -96.315752   -85.456374   -95.251462   -96.096792
#
# sample_id         SRR15032094  SRR15032095  SRR15032096  SRR15032103  \
# name
# (R)-Pantothenate     0.000000     0.000000     0.000000     0.000000
# (R)-lactate          0.000000     0.000000     0.000000   -17.681183
# (S)-lactate          0.000000     0.000000     0.000000     0.000000
# (S)-malate(2-)     -39.296585    -3.595775   -35.085640   -23.427508
# 2-Oxobutanoate     -96.452429   -97.178458   -93.649651   -95.180926
#
# sample_id         SRR15032108  SRR15032109  ...  SRR15032449  SRR15032450  \
# name                                        ...
# (R)-Pantothenate     0.000000    -0.000259  ...     0.000000     0.000000
# (R)-lactate          0.000000     0.000000  ...     0.000000     0.000000
# (S)-lactate          0.000000     0.000000  ...     0.000000     0.000000
# (S)-malate(2-)     -45.746246   -51.436974  ...   -53.086763   -32.514195
# 2-Oxobutanoate     -94.705061   -95.798799  ...   -97.082411   -94.279706
#
# sample_id         SRR15032453  SRR15032485  SRR15032487  SRR15032493  \
# name
# (R)-Pantothenate     0.000000     0.000000     0.000000     0.000000
# (R)-lactate        -40.633408     0.000000     0.000000     0.000000
# (S)-lactate        -40.716894     0.000000     0.000000     0.000000
# (S)-malate(2-)     -67.783298   -58.626274     0.000000   -48.522906
# 2-Oxobutanoate     -85.434325   -86.389571   -94.918512   -88.866988
#
# sample_id         SRR15032495  SRR15032502  SRR15032505  SRR15032510
# name
# (R)-Pantothenate     0.000000     0.000000     0.000000    -0.000337
# (R)-lactate         -0.107810     0.000000     0.000000     0.000000
# (S)-lactate          0.000000     0.000000     0.000000     0.000000
# (S)-malate(2-)     -40.190370   -70.018554     0.000000   -41.956495
# 2-Oxobutanoate     -87.761565   -97.024848   -66.099114   -91.857611
#
# [5 rows x 81 columns]

# %%
#top_imports = imports.nlargest(40, "flux")

# %%
label_map = pd.Series({"high_fiber": "tomato", "fermented": "pink", "western": "seagreen"})
labels = merged_with_annotations[["sample_id", "medium"]].drop_duplicates().set_index("sample_id")
labels["status"] = label_map[labels.medium].values

Prevotella_filtered_heatmap = sns.clustermap(
    np.log10(-imports + 1e-5), # Convert to positive fluxes and log-transform
    figsize=(12, 20),           # we have way more reactions than samples here
    col_colors=labels.status,   # must be a seried with one color for each sample ID
    yticklabels = True      
)

Prevotella_filtered_heatmap

Prevotella_filtered_heatmap.savefig("Prevotella_filtered_heatmap2.png")

# %% [markdown]
# # statistical tests

# %%
from micom.stats import compare_groups

long_imports = merged[merged.direction == "import"]
long_imports["flux"] = long_imports["flux"].abs()
# Out:
# /tmp/ipykernel_753736/4173580547.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_imports["flux"] = long_imports["flux"].abs()

# %% [markdown]
# long_imports comes from merged, which comes from Prevotella, meaning it contains the exchange fluxes

# %%
long_imports
# Out:
#       Unnamed: 0_x       taxon    sample_id  tolerance          reaction  \
# 0            23085  Prevotella  SRR15032095   0.000001           EX_h(e)
# 1            23092  Prevotella  SRR15032095   0.000001        EX_malt(e)
# 2            23093  Prevotella  SRR15032095   0.000001          EX_pi(e)
# 3            23094  Prevotella  SRR15032095   0.000001       EX_acnam(e)
# 5            23110  Prevotella  SRR15032095   0.000001         EX_ade(e)
# ...            ...         ...          ...        ...               ...
# 9016       2504819  Prevotella  SRR15032510   0.000001         EX_fe3(e)
# 9017       2504820  Prevotella  SRR15032510   0.000001  EX_MGlcn59_rl(e)
# 9018       2504821  Prevotella  SRR15032510   0.000001         EX_gsn(e)
# 9019       2504824  Prevotella  SRR15032510   0.000001        EX_succ(e)
# 9023       2504829  Prevotella  SRR15032510   0.000001  EX_MGlcn40_rl(e)
#
#            flux  abundance     metabolite direction  Unnamed: 0_y  \
# 0     97.331225   0.215981           h[e]    import            17
# 1      0.027801   0.215981        malt[e]    import            17
# 2     64.707708   0.215981          pi[e]    import            17
# 3      5.268732   0.215981       acnam[e]    import            17
# 5     48.821904   0.215981         ade[e]    import            17
# ...         ...        ...            ...       ...           ...
# 9016   0.000158   0.022368         fe3[e]    import           306
# 9017   0.000004   0.022368  MGlcn59_rl[e]    import           306
# 9018   8.337185   0.022368         gsn[e]    import           306
# 9019  53.906947   0.022368        succ[e]    import           306
# 9023   0.000003   0.022368  MGlcn40_rl[e]    import           306
#
#                    description  time_point                file  found_taxa  \
# 0              High fiber diet           6  SRR15032095.pickle        17.0
# 1              High fiber diet           6  SRR15032095.pickle        17.0
# 2              High fiber diet           6  SRR15032095.pickle        17.0
# 3              High fiber diet           6  SRR15032095.pickle        17.0
# 5              High fiber diet           6  SRR15032095.pickle        17.0
# ...                        ...         ...                 ...         ...
# 9016  High fermented food diet           2  SRR15032510.pickle        21.0
# 9017  High fermented food diet           2  SRR15032510.pickle        21.0
# 9018  High fermented food diet           2  SRR15032510.pickle        21.0
# 9019  High fermented food diet           2  SRR15032510.pickle        21.0
# 9023  High fermented food diet           2  SRR15032510.pickle        21.0
#
#       total_taxa  found_fraction  found_abundance_fraction      medium
# 0           21.0        0.809524                  0.931123  high_fiber
# 1           21.0        0.809524                  0.931123  high_fiber
# 2           21.0        0.809524                  0.931123  high_fiber
# 3           21.0        0.809524                  0.931123  high_fiber
# 5           21.0        0.809524                  0.931123  high_fiber
# ...          ...             ...                       ...         ...
# 9016        28.0        0.750000                  0.881483     western
# 9017        28.0        0.750000                  0.881483     western
# 9018        28.0        0.750000                  0.881483     western
# 9019        28.0        0.750000                  0.881483     western
# 9023        28.0        0.750000                  0.881483     western
#
# [5260 rows x 18 columns]

# %%
tests = compare_groups(long_imports, "medium")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
tests.sort_values(by="q")
# Out:
#         metabolite  log_mean_std         p   n         q
# 0          malt[e]      4.124972  0.000010  49  0.000896
# 0          cgly[e]      2.024023  0.000035  44  0.001552
# 0         glcur[e]      2.415962  0.000097  70  0.002855
# 0         gcald[e]      2.892943  0.000130  31  0.002868
# 0          ptrc[e]      0.728269  0.000202  60  0.003559
# ..             ...           ...       ...  ..       ...
# 0   MGlcn188_rl[e]           NaN       NaN   1       NaN
# 0       MGlcn36[e]           NaN       NaN   1       NaN
# 0   MGlcn181_rl[e]           NaN       NaN   1       NaN
# 0    MGlcn59_rl[e]           NaN       NaN   1       NaN
# 0    MGlcn40_rl[e]           NaN       NaN   1       NaN
#
# [328 rows x 5 columns]

# %%
from plotnine import *
theme_set(theme_minimal())

selected_mets = tests.sort_values(by="q").metabolite[0:4] 

pl = (
    ggplot(long_imports[long_imports.metabolite.isin(selected_mets)])
    + aes(x="medium", y="flux")
    + geom_boxplot() 
    + geom_jitter(width=.2)
    + scale_y_log10()
    + facet_wrap("~ metabolite")
)
pl
# Out:
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ggplot: (8736193468462)>

# %%
from plotnine import *
theme_set(theme_minimal())

selected_mets = tests[tests.q < 0.05].metabolite

#sort_values(by="q").metabolite[0:4] 

pl = (
    ggplot(long_imports[long_imports.metabolite.isin(selected_mets)])
    + aes(x="medium", y="flux")
    + theme(figure_size = (12,4))
    + geom_boxplot() 
    + geom_jitter(width=.2)
    + scale_y_log10()
    + facet_wrap("~ metabolite")
)
pl
# Out:
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ggplot: (8736193244450)>

# %%
#merged_with_host_id = pd.read_csv("/proj/gibbons/sswegle_micom/All the Steps/merged_with_host_id.csv")

# %%
#import pandas as pd
#from micom.viz import plot_exchanges_per_taxon
#from plotnine import *
#theme_set(theme_minimal())
#import warnings
#warnings.simplefilter("ignore")  # don't show warnings
#import numpy as np

#meta = merged_with_host_id.sort_values(by=["host_subject_id", "time_point"])

# %%
from plotnine import *
theme_set(theme_minimal())

selected_mets = tests[tests.q < 0.05].metabolite

#sort_values(by="q").metabolite[0:4] 

pl = (
    ggplot(long_imports[long_imports.metabolite.isin(selected_mets)])
    + aes(x="medium", y="flux")
    + theme(figure_size = (12,4))
    + geom_boxplot() 
    + geom_jitter(width=.2)
    + scale_y_log10()
    + facet_wrap("~ metabolite")
)
pl
# Out:
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ggplot: (8736192729525)>

# %%
tests
# Out:
#         metabolite  log_mean_std         p   n         q
# 0             h[e]      0.059282  0.296321  55  0.565413
# 0          malt[e]      4.124972  0.000010  49  0.000896
# 0            pi[e]      0.156164  0.423219  23  0.636922
# 0         acnam[e]      0.240151  0.279086  81  0.565413
# 0           ade[e]      0.507190  0.000999  53  0.012558
# ..             ...           ...       ...  ..       ...
# 0   MGlcn188_rl[e]           NaN       NaN   1       NaN
# 0       MGlcn36[e]           NaN       NaN   1       NaN
# 0   MGlcn181_rl[e]           NaN       NaN   1       NaN
# 0    MGlcn59_rl[e]           NaN       NaN   1       NaN
# 0    MGlcn40_rl[e]           NaN       NaN   1       NaN
#
# [328 rows x 5 columns]

# %% [markdown]
# need to first sort by q value

# %%
from plotnine import *
theme_set(theme_minimal())

selected_with_q_and_log = tests[tests.q < 0.05].nlargest(10, "log_mean_std")

pl = (
    ggplot(long_imports[long_imports.metabolite.isin(selected_with_q_and_log.metabolite)])
    + aes(x="medium", y="flux")
    + theme(figure_size = (20,10))
    + geom_boxplot() 
    + geom_jitter(width=.2)
    + scale_y_log10()
    + facet_wrap("~ metabolite")
)
pl
# Out:
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ggplot: (8736193270185)>

# %%
selected_with_q_and_log
# Out:
#   metabolite  log_mean_std         p   n         q
# 0    malt[e]      4.124972  0.000010  49  0.000896
# 0   gcald[e]      2.892943  0.000130  31  0.002868
# 0   glcur[e]      2.415962  0.000097  70  0.002855
# 0    cgly[e]      2.024023  0.000035  44  0.001552
# 0     so4[e]      1.410549  0.002158  81  0.023733
# 0     fe3[e]      1.106089  0.000973  41  0.012558
# 0    ptrc[e]      0.728269  0.000202  60  0.003559
# 0     ade[e]      0.507190  0.000999  53  0.012558
# 0   ala_L[e]      0.400734  0.003810  50  0.033530
# 0     orn[e]      0.295960  0.003477  81  0.033530

# %% [markdown]
# merging with annotations so the real names of the metabolites show

# %%
annotations = pd.read_csv("/proj/gibbons/sswegle_micom/Res_Saves/annotations_swegle.csv")

# %%
tests_merged_with_annotations = tests.merge(annotations, on="metabolite")

# %%
Prevotella_merged_with_annotations = long_imports.merge(annotations, on="metabolite")

# %%
tests_merged_with_annotations
# Out:
#          metabolite  log_mean_std         p   n         q           reaction  \
# 0              h[e]      0.059282  0.296321  55  0.565413            EX_h(e)
# 1           malt[e]      4.124972  0.000010  49  0.000896         EX_malt(e)
# 2             pi[e]      0.156164  0.423219  23  0.636922           EX_pi(e)
# 3          acnam[e]      0.240151  0.279086  81  0.565413        EX_acnam(e)
# 4            ade[e]      0.507190  0.000999  53  0.012558          EX_ade(e)
# ..              ...           ...       ...  ..       ...                ...
# 323  MGlcn188_rl[e]           NaN       NaN   1       NaN  EX_MGlcn188_rl(e)
# 324      MGlcn36[e]           NaN       NaN   1       NaN      EX_MGlcn36(e)
# 325  MGlcn181_rl[e]           NaN       NaN   1       NaN  EX_MGlcn181_rl(e)
# 326   MGlcn59_rl[e]           NaN       NaN   1       NaN   EX_MGlcn59_rl(e)
# 327   MGlcn40_rl[e]           NaN       NaN   1       NaN   EX_MGlcn40_rl(e)
#
#                                     name  molecular_weight  C_number  \
# 0                                 proton          1.007940         0
# 1                                Maltose        342.296480        12
# 2                      hydrogenphosphate         95.979301         0
# 3                    N-acetylneuraminate        308.261920        11
# 4                                Adenine        135.126700         5
# ..                                   ...               ...       ...
# 323  released mucin-type O-glycan No 188       1532.367320        58
# 324            mucin-type O-glycan No 36               NaN        46
# 325  released mucin-type O-glycan No 181       1938.752360        74
# 326   released mucin-type O-glycan No 59       2247.034160        86
# 327   released mucin-type O-glycan No 40       1244.156440        48
#
#      N_number       hmdb                                              inchi  \
# 0           0  HMDB01362                                  InChI=1S/p+1/i/hH
# 1           0  HMDB00163                                                NaN
# 2           0  HMDB00973        InChI=1S/H3O4P/c1-5(2,3)4/h(H3,1,2,3,4)/p-2
# 3           1  HMDB00230                                                NaN
# 4           5  HMDB00034  InChI=1S/C5H5N5/c6-4-3-5(9-1-7-3)10-2-8-4/h1-2...
# ..        ...        ...                                                ...
# 323         5        NaN                                                NaN
# 324         2        NaN                                                NaN
# 325         7        NaN                                                NaN
# 326         7        NaN                                                NaN
# 327         3        NaN                                                NaN
#
#     kegg.compound  pubchem.compound         reaction.1
# 0          C00282            1038.0            EX_h(e)
# 1          C00208          439186.0         EX_malt(e)
# 2          C00009            1004.0           EX_pi(e)
# 3          C19910          439197.0        EX_acnam(e)
# 4          C00147             190.0          EX_ade(e)
# ..            ...               ...                ...
# 323           NaN               NaN  EX_MGlcn188_rl(e)
# 324           NaN               NaN      EX_MGlcn36(e)
# 325           NaN               NaN  EX_MGlcn181_rl(e)
# 326           NaN               NaN   EX_MGlcn59_rl(e)
# 327           NaN               NaN   EX_MGlcn40_rl(e)
#
# [328 rows x 15 columns]

# %%
Prevotella_merged_with_annotations
# Out:
#       Unnamed: 0_x       taxon    sample_id  tolerance         reaction_x  \
# 0            23085  Prevotella  SRR15032095   0.000001            EX_h(e)
# 1            37977  Prevotella  SRR15032094   0.000001            EX_h(e)
# 2            59495  Prevotella  SRR15032087   0.000001            EX_h(e)
# 3            68872  Prevotella  SRR15032079   0.000001            EX_h(e)
# 4           123756  Prevotella  SRR15032096   0.000001            EX_h(e)
# ...            ...         ...          ...        ...                ...
# 5255       2504814  Prevotella  SRR15032510   0.000001  EX_MGlcn188_rl(e)
# 5256       2504815  Prevotella  SRR15032510   0.000001      EX_MGlcn36(e)
# 5257       2504817  Prevotella  SRR15032510   0.000001  EX_MGlcn181_rl(e)
# 5258       2504820  Prevotella  SRR15032510   0.000001   EX_MGlcn59_rl(e)
# 5259       2504829  Prevotella  SRR15032510   0.000001   EX_MGlcn40_rl(e)
#
#            flux  abundance      metabolite direction  Unnamed: 0_y  ...  \
# 0     97.331225   0.215981            h[e]    import            17  ...
# 1     97.260081   0.225517            h[e]    import            16  ...
# 2     83.321639   0.052390            h[e]    import             9  ...
# 3     98.590495   0.311711            h[e]    import             1  ...
# 4      5.243905   0.025730            h[e]    import            18  ...
# ...         ...        ...             ...       ...           ...  ...
# 5255   0.000002   0.022368  MGlcn188_rl[e]    import           306  ...
# 5256   0.000003   0.022368      MGlcn36[e]    import           306  ...
# 5257   0.000002   0.022368  MGlcn181_rl[e]    import           306  ...
# 5258   0.000004   0.022368   MGlcn59_rl[e]    import           306  ...
# 5259   0.000003   0.022368   MGlcn40_rl[e]    import           306  ...
#
#              reaction_y                                 name molecular_weight  \
# 0               EX_h(e)                               proton          1.00794
# 1               EX_h(e)                               proton          1.00794
# 2               EX_h(e)                               proton          1.00794
# 3               EX_h(e)                               proton          1.00794
# 4               EX_h(e)                               proton          1.00794
# ...                 ...                                  ...              ...
# 5255  EX_MGlcn188_rl(e)  released mucin-type O-glycan No 188       1532.36732
# 5256      EX_MGlcn36(e)            mucin-type O-glycan No 36              NaN
# 5257  EX_MGlcn181_rl(e)  released mucin-type O-glycan No 181       1938.75236
# 5258   EX_MGlcn59_rl(e)   released mucin-type O-glycan No 59       2247.03416
# 5259   EX_MGlcn40_rl(e)   released mucin-type O-glycan No 40       1244.15644
#
#       C_number  N_number       hmdb              inchi kegg.compound  \
# 0            0         0  HMDB01362  InChI=1S/p+1/i/hH        C00282
# 1            0         0  HMDB01362  InChI=1S/p+1/i/hH        C00282
# 2            0         0  HMDB01362  InChI=1S/p+1/i/hH        C00282
# 3            0         0  HMDB01362  InChI=1S/p+1/i/hH        C00282
# 4            0         0  HMDB01362  InChI=1S/p+1/i/hH        C00282
# ...        ...       ...        ...                ...           ...
# 5255        58         5        NaN                NaN           NaN
# 5256        46         2        NaN                NaN           NaN
# 5257        74         7        NaN                NaN           NaN
# 5258        86         7        NaN                NaN           NaN
# 5259        48         3        NaN                NaN           NaN
#
#      pubchem.compound         reaction.1
# 0              1038.0            EX_h(e)
# 1              1038.0            EX_h(e)
# 2              1038.0            EX_h(e)
# 3              1038.0            EX_h(e)
# 4              1038.0            EX_h(e)
# ...               ...                ...
# 5255              NaN  EX_MGlcn188_rl(e)
# 5256              NaN      EX_MGlcn36(e)
# 5257              NaN  EX_MGlcn181_rl(e)
# 5258              NaN   EX_MGlcn59_rl(e)
# 5259              NaN   EX_MGlcn40_rl(e)
#
# [5260 rows x 28 columns]

# %% [markdown]
# re making the graphs, with the actual metabolite names now

# %%
from plotnine import *
theme_set(theme_minimal())

Prevotella_with_name = tests_merged_with_annotations[tests_merged_with_annotations.q < 0.05].nlargest(6, "log_mean_std")

Prevotella_filtered_metabolites = (
    ggplot(Prevotella_merged_with_annotations[Prevotella_merged_with_annotations.name.isin(Prevotella_with_name.name)])
    + aes(x="medium", y="flux")
    + theme(figure_size = (12,4))
    + geom_boxplot() 
    + geom_jitter(width=.2)
    + scale_y_log10()
    + facet_wrap("~ name")
)

Prevotella_filtered_metabolites

#Prevotella_filtered_metabolites.save("Prevotella_filtered_metabolites.png")
# Out:
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ggplot: (8736243068663)>

# %%
Prevotella_filtered_metabolites
# Out:
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ggplot: (8736243068663)>

# %%
from plotnine import *
theme_set(theme_minimal())

Prevotella_with_name = tests_merged_with_annotations[tests_merged_with_annotations.q < 0.05].nlargest(4, "log_mean_std")

Prevotella_metabolites_with_time = (
    ggplot(Prevotella_merged_with_annotations[Prevotella_merged_with_annotations.name.isin(Prevotella_with_name.name)])
    + aes(x="medium", y="flux", color = "time_point")
    + theme(figure_size = (12,4))
    + geom_boxplot() 
    + geom_jitter(width=.2)
    + scale_y_log10()
    + facet_wrap("~ name")
)

Prevotella_metabolites_with_time
# Out:
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ggplot: (8736192860004)>
