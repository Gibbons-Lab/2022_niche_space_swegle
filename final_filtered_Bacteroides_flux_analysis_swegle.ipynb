# %%
import pandas as pd

# %%
exchanges = pd.read_csv("/proj/gibbons/sswegle_micom/Res_Saves/exchanges_swegle.csv")

# %% [markdown]
# now I will select exchanges for only one taxa

# %%
Bacteroides = exchanges[exchanges.taxon == "Bacteroides"]
Bacteroides
# Out:
#         Unnamed: 0        taxon    sample_id  tolerance          reaction  \
# 157           1058  Bacteroides  SRR15032086   0.000001           EX_h(e)
# 158           1065  Bacteroides  SRR15032086   0.000001        EX_malt(e)
# 159           1066  Bacteroides  SRR15032086   0.000001          EX_pi(e)
# 160           1067  Bacteroides  SRR15032086   0.000001       EX_acnam(e)
# 161           1075  Bacteroides  SRR15032086   0.000001         EX_gly(e)
# ...            ...          ...          ...        ...               ...
# 494936     2531844  Bacteroides  SRR15032514   0.000001         EX_fe3(e)
# 494937     2531846  Bacteroides  SRR15032514   0.000001      EX_lald_L(e)
# 494938     2531848  Bacteroides  SRR15032514   0.000001         EX_gsn(e)
# 494939     2531851  Bacteroides  SRR15032514   0.000001        EX_succ(e)
# 494940     2531854  Bacteroides  SRR15032514   0.000001  EX_metsox_S_L(e)
#
#              flux  abundance     metabolite direction
# 157    -96.393233   0.398846           h[e]    import
# 158     -0.007457   0.398846        malt[e]    import
# 159    -26.506140   0.398846          pi[e]    import
# 160      0.776942   0.398846       acnam[e]    export
# 161      0.134445   0.398846         gly[e]    export
# ...           ...        ...            ...       ...
# 494936  -0.006473   0.356387         fe3[e]    import
# 494937 -26.861597   0.356387      lald_L[e]    import
# 494938 -14.617869   0.356387         gsn[e]    import
# 494939 -40.532263   0.356387        succ[e]    import
# 494940  -0.041487   0.356387  metsox_S_L[e]    import
#
# [43175 rows x 9 columns]

# %% [markdown]
# add metadata so can add labels

# %%
metadata = pd.read_csv("/proj/gibbons/sswegle_micom/All the Steps/metadata_swegle.csv")
metadata
# Out:
#      Unnamed: 0    sample_id               description  time_point  \
# 0             0  SRR15032078           High fiber diet           8
# 1             1  SRR15032079           High fiber diet           4
# 2             2  SRR15032080  High fermented food diet           3
# 3             3  SRR15032081  High fermented food diet           2
# 4             4  SRR15032082           High fiber diet           7
# ..          ...          ...                       ...         ...
# 306         306  SRR15032510  High fermented food diet           2
# 307         307  SRR15032511           High fiber diet           6
# 308         308  SRR15032512  High fermented food diet           7
# 309         309  SRR15032513  High fermented food diet           6
# 310         310  SRR15032514           High fiber diet           9
#
#                    file  found_taxa  total_taxa  found_fraction  \
# 0    SRR15032078.pickle        24.0        37.0        0.648649
# 1    SRR15032079.pickle        21.0        25.0        0.840000
# 2    SRR15032080.pickle        16.0        27.0        0.592593
# 3    SRR15032081.pickle        11.0        17.0        0.647059
# 4    SRR15032082.pickle        23.0        33.0        0.696970
# ..                  ...         ...         ...             ...
# 306  SRR15032510.pickle        21.0        28.0        0.750000
# 307  SRR15032511.pickle        22.0        32.0        0.687500
# 308  SRR15032512.pickle        23.0        37.0        0.621622
# 309  SRR15032513.pickle        19.0        30.0        0.633333
# 310  SRR15032514.pickle        24.0        37.0        0.648649
#
#      found_abundance_fraction      medium
# 0                    0.889586  high_fiber
# 1                    0.942212  high_fiber
# 2                    0.855661   fermented
# 3                    0.898909     western
# 4                    0.908204  high_fiber
# ..                        ...         ...
# 306                  0.881483     western
# 307                  0.799526  high_fiber
# 308                  0.843232   fermented
# 309                  0.839063   fermented
# 310                  0.740106     western
#
# [311 rows x 10 columns]

# %%
filtered_meta = metadata[metadata.time_point < 8]

# %%
merged = Bacteroides.merge(filtered_meta, on="sample_id")
merged
# Out:
#        Unnamed: 0_x        taxon    sample_id  tolerance          reaction  \
# 0              6515  Bacteroides  SRR15032081   0.000001  EX_MGlcn98_rl(e)
# 1              6518  Bacteroides  SRR15032081   0.000001           EX_h(e)
# 2              6519  Bacteroides  SRR15032081   0.000001     EX_MGlcn46(e)
# 3              6520  Bacteroides  SRR15032081   0.000001  EX_MGlcn50_rl(e)
# 4              6522  Bacteroides  SRR15032081   0.000001     EX_MGlcn59(e)
# ...             ...          ...          ...        ...               ...
# 33458       2523581  Bacteroides  SRR15032512   0.000001        EX_etoh(e)
# 33459       2523588  Bacteroides  SRR15032512   0.000001         EX_fe3(e)
# 33460       2523590  Bacteroides  SRR15032512   0.000001      EX_lald_L(e)
# 33461       2523592  Bacteroides  SRR15032512   0.000001         EX_gsn(e)
# 33462       2523595  Bacteroides  SRR15032512   0.000001        EX_succ(e)
#
#             flux  abundance     metabolite direction  Unnamed: 0_y  \
# 0       0.000001   0.203834  MGlcn98_rl[e]    export             3
# 1     -40.326659   0.203834           h[e]    import             3
# 2       0.000003   0.203834     MGlcn46[e]    export             3
# 3       0.000003   0.203834  MGlcn50_rl[e]    export             3
# 4       0.000003   0.203834     MGlcn59[e]    export             3
# ...          ...        ...            ...       ...           ...
# 33458  58.187042   0.488549        etoh[e]    export           308
# 33459  -0.002909   0.488549         fe3[e]    import           308
# 33460 -20.775149   0.488549      lald_L[e]    import           308
# 33461  -4.450126   0.488549         gsn[e]    import           308
# 33462  -9.074075   0.488549        succ[e]    import           308
#
#                     description  time_point                file  found_taxa  \
# 0      High fermented food diet           2  SRR15032081.pickle        11.0
# 1      High fermented food diet           2  SRR15032081.pickle        11.0
# 2      High fermented food diet           2  SRR15032081.pickle        11.0
# 3      High fermented food diet           2  SRR15032081.pickle        11.0
# 4      High fermented food diet           2  SRR15032081.pickle        11.0
# ...                         ...         ...                 ...         ...
# 33458  High fermented food diet           7  SRR15032512.pickle        23.0
# 33459  High fermented food diet           7  SRR15032512.pickle        23.0
# 33460  High fermented food diet           7  SRR15032512.pickle        23.0
# 33461  High fermented food diet           7  SRR15032512.pickle        23.0
# 33462  High fermented food diet           7  SRR15032512.pickle        23.0
#
#        total_taxa  found_fraction  found_abundance_fraction     medium
# 0            17.0        0.647059                  0.898909    western
# 1            17.0        0.647059                  0.898909    western
# 2            17.0        0.647059                  0.898909    western
# 3            17.0        0.647059                  0.898909    western
# 4            17.0        0.647059                  0.898909    western
# ...           ...             ...                       ...        ...
# 33458        37.0        0.621622                  0.843232  fermented
# 33459        37.0        0.621622                  0.843232  fermented
# 33460        37.0        0.621622                  0.843232  fermented
# 33461        37.0        0.621622                  0.843232  fermented
# 33462        37.0        0.621622                  0.843232  fermented
#
# [33463 rows x 18 columns]

# %%
annotations = pd.read_csv("/proj/gibbons/sswegle_micom/Res_Saves/annotations_swegle.csv")

# %%
merged_with_annotations = merged.merge(annotations, on="metabolite")

# %%
merged_with_annotations.columns
# Out:
# Index(['Unnamed: 0_x', 'taxon', 'sample_id', 'tolerance', 'reaction_x', 'flux',
#        'abundance', 'metabolite', 'direction', 'Unnamed: 0_y', 'description',
#        'time_point', 'file', 'found_taxa', 'total_taxa', 'found_fraction',
#        'found_abundance_fraction', 'medium', 'reaction_y', 'name',
#        'molecular_weight', 'C_number', 'N_number', 'hmdb', 'inchi',
#        'kegg.compound', 'pubchem.compound', 'reaction.1'],
#       dtype='object')

# %%
import pandas as pd

imports = pd.pivot_table(
    merged_with_annotations[merged_with_annotations.direction == "import"], 
    index="name", 
    columns="sample_id", 
    values="flux",
    fill_value=0  # if the reactions is absent in a sample there is no flux
)

imports.head()
# Out:
# sample_id             SRR15032079  SRR15032080  SRR15032081  SRR15032082  \
# name
# (R)-lactate            -86.816854   -15.585368   -39.328883   -17.677277
# (S)-lactaldehyde       -20.156959   -27.723266   -70.202352   -54.277078
# (S)-lactate            -85.887518   -28.483904   -23.764889   -12.677364
# (S)-malate(2-)           0.000000     0.000000     0.000000     0.000000
# (S)-propane-1,2-diol     0.000000     0.000000     0.000000   -45.411840
#
# sample_id             SRR15032083  SRR15032084  SRR15032087  SRR15032089  \
# name
# (R)-lactate             -0.015387   -35.225454   -84.473523   -52.378001
# (S)-lactaldehyde       -38.319520   -17.248252   -47.953040   -17.612197
# (S)-lactate              0.000000   -20.054517   -84.711905   -38.472838
# (S)-malate(2-)           0.000000     0.000000     0.000000     0.000000
# (S)-propane-1,2-diol   -79.374832   -17.223887     0.000000     0.000000
#
# sample_id             SRR15032092  SRR15032094  ...  SRR15032501  SRR15032502  \
# name                                            ...
# (R)-lactate            -76.509362   -64.890259  ...   -54.768393   -77.296722
# (S)-lactaldehyde       -12.721893   -12.707006  ...   -22.502610    -9.293178
# (S)-lactate            -67.794698   -60.931545  ...   -52.113928   -48.288200
# (S)-malate(2-)           0.000000     0.000000  ...     0.000000     0.000000
# (S)-propane-1,2-diol     0.000000     0.000000  ...     0.000000     0.000000
#
# sample_id             SRR15032503  SRR15032505  SRR15032508  SRR15032509  \
# name
# (R)-lactate            -17.061985   -40.062123   -72.730646     0.000000
# (S)-lactaldehyde       -20.356339   -65.344154   -28.584523   -44.663737
# (S)-lactate            -26.540938   -36.926340   -60.314286     0.000000
# (S)-malate(2-)           0.000000   -23.012487     0.000000     0.000000
# (S)-propane-1,2-diol   -59.175301     0.000000     0.000000   -69.506857
#
# sample_id             SRR15032510  SRR15032511  SRR15032512  SRR15032513
# name
# (R)-lactate            -40.741521    -3.351176   -44.499249   -72.350169
# (S)-lactaldehyde       -26.511540   -69.131896   -20.775149   -40.909889
# (S)-lactate              0.000000   -20.538992   -18.279189    -7.754491
# (S)-malate(2-)           0.000000    -3.969885     0.000000     0.000000
# (S)-propane-1,2-diol    -2.438864   -13.084249     0.000000     0.000000
#
# [5 rows x 245 columns]

# %%
import seaborn as sns
import numpy as np

label_map = pd.Series({"high_fiber": "tomato", "fermented": "pink", "western": "seagreen"})
labels = merged_with_annotations[["sample_id", "medium"]].drop_duplicates().set_index("sample_id")
labels["status"] = label_map[labels.medium].values

test_heat_map = sns.clustermap(
    np.log10(-imports + 1e-6), # Convert to positive fluxes and log-transform
    figsize=(12, 24),           # we have way more reactions than samples here
    col_colors=labels.status   # must be a series with one color for each sample ID 
)

#test_heat_map.savefig("testing_saving_heatmaps.png")
# Out:
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/seaborn/matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
imports
# Out:
# sample_id                 SRR15032079  SRR15032080  SRR15032081  SRR15032082  \
# name
# (R)-lactate                -86.816854   -15.585368   -39.328883   -17.677277
# (S)-lactaldehyde           -20.156959   -27.723266   -70.202352   -54.277078
# (S)-lactate                -85.887518   -28.483904   -23.764889   -12.677364
# (S)-malate(2-)               0.000000     0.000000     0.000000     0.000000
# (S)-propane-1,2-diol         0.000000     0.000000     0.000000   -45.411840
# ...                               ...          ...          ...          ...
# sulfate                      0.000000     0.000000    -0.003259     0.000000
# taurocholate                 0.000000     0.000000     0.000000     0.000000
# tetradecanoate (n-C14:0)   -17.566062   -17.774508   -18.113649   -20.937298
# thiosulfate(2-)              0.000000     0.000000     0.000000     0.000000
# uracil                      -6.153501   -79.525837   -72.350936   -84.675832
#
# sample_id                 SRR15032083  SRR15032084  SRR15032087  SRR15032089  \
# name
# (R)-lactate                 -0.015387   -35.225454   -84.473523   -52.378001
# (S)-lactaldehyde           -38.319520   -17.248252   -47.953040   -17.612197
# (S)-lactate                  0.000000   -20.054517   -84.711905   -38.472838
# (S)-malate(2-)               0.000000     0.000000     0.000000     0.000000
# (S)-propane-1,2-diol       -79.374832   -17.223887     0.000000     0.000000
# ...                               ...          ...          ...          ...
# sulfate                      0.000000     0.000000    -1.487929     0.000000
# taurocholate                 0.000000     0.000000     0.000000     0.000000
# tetradecanoate (n-C14:0)   -19.890507   -12.733975   -15.117230    -4.391841
# thiosulfate(2-)              0.000000     0.000000     0.000000     0.000000
# uracil                     -87.571335   -54.636958   -76.208262   -24.499750
#
# sample_id                 SRR15032092  SRR15032094  ...  SRR15032501  \
# name                                                ...
# (R)-lactate                -76.509362   -64.890259  ...   -54.768393
# (S)-lactaldehyde           -12.721893   -12.707006  ...   -22.502610
# (S)-lactate                -67.794698   -60.931545  ...   -52.113928
# (S)-malate(2-)               0.000000     0.000000  ...     0.000000
# (S)-propane-1,2-diol         0.000000     0.000000  ...     0.000000
# ...                               ...          ...  ...          ...
# sulfate                     -0.002492     0.000000  ...    -0.003930
# taurocholate                 0.000000     0.000000  ...     0.000000
# tetradecanoate (n-C14:0)    -8.160265   -13.161159  ...    -3.764558
# thiosulfate(2-)             -0.011551     0.000000  ...     0.000000
# uracil                     -54.470637   -41.938413  ...   -48.771616
#
# sample_id                 SRR15032502  SRR15032503  SRR15032505  SRR15032508  \
# name
# (R)-lactate                -77.296722   -17.061985   -40.062123   -72.730646
# (S)-lactaldehyde            -9.293178   -20.356339   -65.344154   -28.584523
# (S)-lactate                -48.288200   -26.540938   -36.926340   -60.314286
# (S)-malate(2-)               0.000000     0.000000   -23.012487     0.000000
# (S)-propane-1,2-diol         0.000000   -59.175301     0.000000     0.000000
# ...                               ...          ...          ...          ...
# sulfate                     -0.154950    -0.085855    -0.532963     0.000000
# taurocholate                 0.000000     0.000000     0.000000     0.000000
# tetradecanoate (n-C14:0)   -10.996548   -14.449818   -30.604285    -6.770194
# thiosulfate(2-)             -0.006227     0.000000     0.000000     0.000000
# uracil                     -43.511042   -70.415371    -6.674322   -80.967519
#
# sample_id                 SRR15032509  SRR15032510  SRR15032511  SRR15032512  \
# name
# (R)-lactate                  0.000000   -40.741521    -3.351176   -44.499249
# (S)-lactaldehyde           -44.663737   -26.511540   -69.131896   -20.775149
# (S)-lactate                  0.000000     0.000000   -20.538992   -18.279189
# (S)-malate(2-)               0.000000     0.000000    -3.969885     0.000000
# (S)-propane-1,2-diol       -69.506857    -2.438864   -13.084249     0.000000
# ...                               ...          ...          ...          ...
# sulfate                      0.000000    -0.004466     0.000000    -0.030804
# taurocholate                 0.000000     0.000000     0.000000     0.000000
# tetradecanoate (n-C14:0)   -21.597344   -23.767571   -21.105948    -6.892702
# thiosulfate(2-)              0.000000     0.000000    -0.001099     0.000000
# uracil                     -89.364507   -48.223915   -73.520959   -34.889209
#
# sample_id                 SRR15032513
# name
# (R)-lactate                -72.350169
# (S)-lactaldehyde           -40.909889
# (S)-lactate                 -7.754491
# (S)-malate(2-)               0.000000
# (S)-propane-1,2-diol         0.000000
# ...                               ...
# sulfate                     -0.722717
# taurocholate                 0.000000
# tetradecanoate (n-C14:0)    -9.250042
# thiosulfate(2-)             -0.010524
# uracil                     -79.192469
#
# [407 rows x 245 columns]

# %%
import pandas as pd

imports = pd.pivot_table(
    merged_with_annotations[(merged_with_annotations.direction == "import") & (merged_with_annotations.flux < -1e-1)], 
    index="name", 
    columns="sample_id", 
    values="flux",
    fill_value=0  # if the reactions is absent in a sample there is no flux
)

imports.head()
# Out:
# sample_id             SRR15032079  SRR15032080  SRR15032081  SRR15032082  \
# name
# (R)-lactate            -86.816854   -15.585368   -39.328883   -17.677277
# (S)-lactaldehyde       -20.156959   -27.723266   -70.202352   -54.277078
# (S)-lactate            -85.887518   -28.483904   -23.764889   -12.677364
# (S)-malate(2-)           0.000000     0.000000     0.000000     0.000000
# (S)-propane-1,2-diol     0.000000     0.000000     0.000000   -45.411840
#
# sample_id             SRR15032083  SRR15032084  SRR15032087  SRR15032089  \
# name
# (R)-lactate              0.000000   -35.225454   -84.473523   -52.378001
# (S)-lactaldehyde       -38.319520   -17.248252   -47.953040   -17.612197
# (S)-lactate              0.000000   -20.054517   -84.711905   -38.472838
# (S)-malate(2-)           0.000000     0.000000     0.000000     0.000000
# (S)-propane-1,2-diol   -79.374832   -17.223887     0.000000     0.000000
#
# sample_id             SRR15032092  SRR15032094  ...  SRR15032501  SRR15032502  \
# name                                            ...
# (R)-lactate            -76.509362   -64.890259  ...   -54.768393   -77.296722
# (S)-lactaldehyde       -12.721893   -12.707006  ...   -22.502610    -9.293178
# (S)-lactate            -67.794698   -60.931545  ...   -52.113928   -48.288200
# (S)-malate(2-)           0.000000     0.000000  ...     0.000000     0.000000
# (S)-propane-1,2-diol     0.000000     0.000000  ...     0.000000     0.000000
#
# sample_id             SRR15032503  SRR15032505  SRR15032508  SRR15032509  \
# name
# (R)-lactate            -17.061985   -40.062123   -72.730646     0.000000
# (S)-lactaldehyde       -20.356339   -65.344154   -28.584523   -44.663737
# (S)-lactate            -26.540938   -36.926340   -60.314286     0.000000
# (S)-malate(2-)           0.000000   -23.012487     0.000000     0.000000
# (S)-propane-1,2-diol   -59.175301     0.000000     0.000000   -69.506857
#
# sample_id             SRR15032510  SRR15032511  SRR15032512  SRR15032513
# name
# (R)-lactate            -40.741521    -3.351176   -44.499249   -72.350169
# (S)-lactaldehyde       -26.511540   -69.131896   -20.775149   -40.909889
# (S)-lactate              0.000000   -20.538992   -18.279189    -7.754491
# (S)-malate(2-)           0.000000    -3.969885     0.000000     0.000000
# (S)-propane-1,2-diol    -2.438864   -13.084249     0.000000     0.000000
#
# [5 rows x 245 columns]

# %%
#top_imports = imports.nlargest(40, "flux")

# %%
label_map = pd.Series({"high_fiber": "tomato", "fermented": "pink", "western": "seagreen"})
labels = merged_with_annotations[["sample_id", "medium"]].drop_duplicates().set_index("sample_id")
labels["status"] = label_map[labels.medium].values

Bacteroides_filtered_heatmap = sns.clustermap(
    np.log10(-imports + 1e-4), # Convert to positive fluxes and log-transform
    figsize=(12, 40),           # we have way more reactions than samples here
    col_colors=labels.status,   # must be a seried with one color for each sample ID
    yticklabels = True      
)

Bacteroides_filtered_heatmap

Bacteroides_filtered_heatmap.savefig("Bacteroides_filtered_heatmap.png")
# Out:
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/seaborn/matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %% [markdown]
# # statistical tests

# %%
from micom.stats import compare_groups

long_imports = merged[merged.direction == "import"]
long_imports["flux"] = long_imports["flux"].abs()
# Out:
# /tmp/ipykernel_1633327/4173580547.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   long_imports["flux"] = long_imports["flux"].abs()

# %%
long_imports
# Out:
#        Unnamed: 0_x        taxon    sample_id  tolerance          reaction  \
# 1              6518  Bacteroides  SRR15032081   0.000001           EX_h(e)
# 7              6525  Bacteroides  SRR15032081   0.000001        EX_malt(e)
# 8              6526  Bacteroides  SRR15032081   0.000001          EX_pi(e)
# 9              6527  Bacteroides  SRR15032081   0.000001       EX_acnam(e)
# 15             6538  Bacteroides  SRR15032081   0.000001  EX_MGlcn57_rl(e)
# ...             ...          ...          ...        ...               ...
# 33457       2523580  Bacteroides  SRR15032512   0.000001         EX_ura(e)
# 33459       2523588  Bacteroides  SRR15032512   0.000001         EX_fe3(e)
# 33460       2523590  Bacteroides  SRR15032512   0.000001      EX_lald_L(e)
# 33461       2523592  Bacteroides  SRR15032512   0.000001         EX_gsn(e)
# 33462       2523595  Bacteroides  SRR15032512   0.000001        EX_succ(e)
#
#             flux  abundance     metabolite direction  Unnamed: 0_y  \
# 1      40.326659   0.203834           h[e]    import             3
# 7       0.000477   0.203834        malt[e]    import             3
# 8      18.557204   0.203834          pi[e]    import             3
# 9      17.630796   0.203834       acnam[e]    import             3
# 15      0.000001   0.203834  MGlcn57_rl[e]    import             3
# ...          ...        ...            ...       ...           ...
# 33457  34.889209   0.488549         ura[e]    import           308
# 33459   0.002909   0.488549         fe3[e]    import           308
# 33460  20.775149   0.488549      lald_L[e]    import           308
# 33461   4.450126   0.488549         gsn[e]    import           308
# 33462   9.074075   0.488549        succ[e]    import           308
#
#                     description  time_point                file  found_taxa  \
# 1      High fermented food diet           2  SRR15032081.pickle        11.0
# 7      High fermented food diet           2  SRR15032081.pickle        11.0
# 8      High fermented food diet           2  SRR15032081.pickle        11.0
# 9      High fermented food diet           2  SRR15032081.pickle        11.0
# 15     High fermented food diet           2  SRR15032081.pickle        11.0
# ...                         ...         ...                 ...         ...
# 33457  High fermented food diet           7  SRR15032512.pickle        23.0
# 33459  High fermented food diet           7  SRR15032512.pickle        23.0
# 33460  High fermented food diet           7  SRR15032512.pickle        23.0
# 33461  High fermented food diet           7  SRR15032512.pickle        23.0
# 33462  High fermented food diet           7  SRR15032512.pickle        23.0
#
#        total_taxa  found_fraction  found_abundance_fraction     medium
# 1            17.0        0.647059                  0.898909    western
# 7            17.0        0.647059                  0.898909    western
# 8            17.0        0.647059                  0.898909    western
# 9            17.0        0.647059                  0.898909    western
# 15           17.0        0.647059                  0.898909    western
# ...           ...             ...                       ...        ...
# 33457        37.0        0.621622                  0.843232  fermented
# 33459        37.0        0.621622                  0.843232  fermented
# 33460        37.0        0.621622                  0.843232  fermented
# 33461        37.0        0.621622                  0.843232  fermented
# 33462        37.0        0.621622                  0.843232  fermented
#
# [18165 rows x 18 columns]

# %%
tests = compare_groups(long_imports, "medium")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
tests.sort_values(by="q")
# Out:
#      metabolite  log_mean_std             p    n             q
# 0        fol[e]      0.917059  1.190082e-30  232  1.178181e-28
# 0      sheme[e]      0.617126  1.174811e-28  243  3.483261e-27
# 0        cu2[e]      0.573069  3.870290e-28  244  3.483261e-27
# 0        zn2[e]      0.572996  3.870030e-28  244  3.483261e-27
# 0        ca2[e]      0.573064  3.870290e-28  244  3.483261e-27
# ..          ...           ...           ...  ...           ...
# 0   MGlcn161[e]           NaN           NaN    1           NaN
# 0        ins[e]           NaN           NaN    1           NaN
# 0        gal[e]           NaN           NaN    1           NaN
# 0     tchola[e]           NaN           NaN    1           NaN
# 0    MGlcn30[e]           NaN           NaN    1           NaN
#
# [407 rows x 5 columns]

# %%
from plotnine import *
theme_set(theme_minimal())

selected_mets = tests.sort_values(by="q").metabolite[0:4] 

pl = (
    ggplot(long_imports[long_imports.metabolite.isin(selected_mets)])
    + aes(x="medium", y="flux")
    + geom_boxplot() 
    + geom_jitter(width=.2)
    + scale_y_log10()
    + facet_wrap("~ metabolite")
)
pl
# Out:
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ggplot: (8780792715548)>

# %%
from plotnine import *
theme_set(theme_minimal())

selected_mets = tests[tests.q < 0.05].metabolite

#sort_values(by="q").metabolite[0:4] 

pl = (
    ggplot(long_imports[long_imports.metabolite.isin(selected_mets)])
    + aes(x="medium", y="flux")
    + theme(figure_size = (12,4))
    + geom_boxplot() 
    + geom_jitter(width=.2)
    + scale_y_log10()
    + facet_wrap("~ metabolite")
)
pl
# Out:
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ggplot: (8780792459096)>

# %%
#merged_with_host_id = pd.read_csv("/proj/gibbons/sswegle_micom/All the Steps/merged_with_host_id.csv")

# %%
#import pandas as pd
#from micom.viz import plot_exchanges_per_taxon
#from plotnine import *
#theme_set(theme_minimal())
#import warnings
#warnings.simplefilter("ignore")  # don't show warnings
#import numpy as np

#meta = merged_with_host_id.sort_values(by=["host_subject_id", "time_point"])

# %%
from plotnine import *
theme_set(theme_minimal())

selected_mets = tests[tests.q < 0.05].metabolite

#sort_values(by="q").metabolite[0:4] 

pl = (
    ggplot(long_imports[long_imports.metabolite.isin(selected_mets)])
    + aes(x="medium", y="flux")
    + theme(figure_size = (12,4))
    + geom_boxplot() 
    + geom_jitter(width=.2)
    + scale_y_log10()
    + facet_wrap("~ metabolite")
)
pl
# Out:
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ggplot: (8780778463335)>

# %%
tests
# Out:
#        metabolite  log_mean_std             p    n             q
# 0            h[e]      0.028934  1.488270e-02  242  4.464810e-02
# 0         malt[e]      3.051077  1.421386e-16  150  8.277481e-16
# 0           pi[e]      0.017584  9.580806e-01  229  9.580806e-01
# 0        acnam[e]      0.806098  2.138788e-01   82  3.548158e-01
# 0   MGlcn57_rl[e]           NaN           NaN   10           NaN
# ..            ...           ...           ...  ...           ...
# 0     MGlcn161[e]           NaN           NaN    1           NaN
# 0          ins[e]           NaN           NaN    1           NaN
# 0          gal[e]           NaN           NaN    1           NaN
# 0       tchola[e]           NaN           NaN    1           NaN
# 0      MGlcn30[e]           NaN           NaN    1           NaN
#
# [407 rows x 5 columns]

# %% [markdown]
# need to first sort by q value

# %%
from plotnine import *
theme_set(theme_minimal())

selected_with_q_and_log = tests[tests.q < 0.05].nlargest(10, "log_mean_std")

pl = (
    ggplot(long_imports[long_imports.metabolite.isin(selected_with_q_and_log.metabolite)])
    + aes(x="medium", y="flux")
    + theme(figure_size = (20,10))
    + geom_boxplot() 
    + geom_jitter(width=.2)
    + scale_y_log10()
    + facet_wrap("~ metabolite")
)
pl
# Out:
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ggplot: (8780778406244)>

# %%
selected_with_q_and_log
# Out:
#    metabolite  log_mean_std             p    n             q
# 0     malt[e]      3.051077  1.421386e-16  150  8.277481e-16
# 0     cgly[e]      2.724712  5.121423e-24  143  4.225174e-23
# 0    pydxn[e]      1.999305  1.315498e-02  170  4.069822e-02
# 0      so4[e]      1.747229  6.524129e-13  143  3.399415e-12
# 0      no2[e]      1.579669  1.534485e-09  133  6.604956e-09
# 0  26dap_M[e]      1.418577  1.748629e-03   24  6.182653e-03
# 0       o2[e]      1.272000  6.793453e-05  116  2.586738e-04
# 0      fol[e]      0.917059  1.190082e-30  232  1.178181e-28
# 0    ocdca[e]      0.714581  3.724376e-06   44  1.474853e-05
# 0    val_L[e]      0.690288  2.129933e-11  142  1.004111e-10

# %% [markdown]
# merging with annotations so the real names of the metabolites show

# %%
annotations = pd.read_csv("/proj/gibbons/sswegle_micom/Res_Saves/annotations_swegle.csv")

# %%
tests_merged_with_annotations = tests.merge(annotations, on="metabolite")

# %%
Bacteroides_merged_with_annotations = long_imports.merge(annotations, on="metabolite")

# %%
tests_merged_with_annotations
# Out:
#         metabolite  log_mean_std             p    n             q  \
# 0             h[e]      0.028934  1.488270e-02  242  4.464810e-02
# 1          malt[e]      3.051077  1.421386e-16  150  8.277481e-16
# 2            pi[e]      0.017584  9.580806e-01  229  9.580806e-01
# 3         acnam[e]      0.806098  2.138788e-01   82  3.548158e-01
# 4    MGlcn57_rl[e]           NaN           NaN   10           NaN
# ..             ...           ...           ...  ...           ...
# 402    MGlcn161[e]           NaN           NaN    1           NaN
# 403         ins[e]           NaN           NaN    1           NaN
# 404         gal[e]           NaN           NaN    1           NaN
# 405      tchola[e]           NaN           NaN    1           NaN
# 406     MGlcn30[e]           NaN           NaN    1           NaN
#
#              reaction                                name  molecular_weight  \
# 0             EX_h(e)                              proton          1.007940
# 1          EX_malt(e)                             Maltose        342.296480
# 2            EX_pi(e)                   hydrogenphosphate         95.979301
# 3         EX_acnam(e)                 N-acetylneuraminate        308.261920
# 4    EX_MGlcn57_rl(e)  released mucin-type O-glycan No 57       1520.399680
# ..                ...                                 ...               ...
# 402    EX_MGlcn161(e)          mucin-type O-glycan No 161               NaN
# 403         EX_ins(e)                             Inosine        268.226080
# 404         EX_gal(e)                         D-Galactose        180.155880
# 405      EX_tchola(e)                        taurocholate        515.703000
# 406     EX_MGlcn30(e)           mucin-type O-glycan No 30               NaN
#
#      C_number  N_number       hmdb  \
# 0           0         0  HMDB01362
# 1          12         0  HMDB00163
# 2           0         0  HMDB00973
# 3          11         1  HMDB00230
# 4          58         5        NaN
# ..        ...       ...        ...
# 402        42         3        NaN
# 403        10         4  HMDB00195
# 404         6         0  HMDB00143
# 405        26         1  HMDB00036
# 406        40         2        NaN
#
#                                            inchi kegg.compound  \
# 0                              InChI=1S/p+1/i/hH        C00282
# 1                                            NaN        C00208
# 2    InChI=1S/H3O4P/c1-5(2,3)4/h(H3,1,2,3,4)/p-2        C00009
# 3                                            NaN        C19910
# 4                                            NaN           NaN
# ..                                           ...           ...
# 402                                          NaN           NaN
# 403                                          NaN        C00294
# 404                                          NaN        C00984
# 405                                          NaN           NaN
# 406                                          NaN           NaN
#
#      pubchem.compound        reaction.1
# 0              1038.0           EX_h(e)
# 1            439186.0        EX_malt(e)
# 2              1004.0          EX_pi(e)
# 3            439197.0       EX_acnam(e)
# 4                 NaN  EX_MGlcn57_rl(e)
# ..                ...               ...
# 402               NaN    EX_MGlcn161(e)
# 403            6021.0         EX_ins(e)
# 404          439357.0         EX_gal(e)
# 405          440567.0      EX_tchola(e)
# 406               NaN     EX_MGlcn30(e)
#
# [407 rows x 15 columns]

# %%
Bacteroides_merged_with_annotations
# Out:
#        Unnamed: 0_x        taxon    sample_id  tolerance      reaction_x  \
# 0              6518  Bacteroides  SRR15032081   0.000001         EX_h(e)
# 1             12558  Bacteroides  SRR15032097   0.000001         EX_h(e)
# 2             19209  Bacteroides  SRR15032095   0.000001         EX_h(e)
# 3             25890  Bacteroides  SRR15032080   0.000001         EX_h(e)
# 4             33110  Bacteroides  SRR15032094   0.000001         EX_h(e)
# ...             ...          ...          ...        ...             ...
# 18160       1866526  Bacteroides  SRR15032439   0.000001  EX_MGlcn161(e)
# 18161       2112177  Bacteroides  SRR15032471   0.000001       EX_ins(e)
# 18162       2403584  Bacteroides  SRR15032499   0.000001       EX_gal(e)
# 18163       2403792  Bacteroides  SRR15032499   0.000001    EX_tchola(e)
# 18164       2500074  Bacteroides  SRR15032510   0.000001   EX_MGlcn30(e)
#
#             flux  abundance   metabolite direction  Unnamed: 0_y  ...  \
# 0      40.326659   0.203834         h[e]    import             3  ...
# 1      89.258930   0.236194         h[e]    import            19  ...
# 2      91.691905   0.201741         h[e]    import            17  ...
# 3      88.583431   0.307169         h[e]    import             2  ...
# 4      95.120794   0.356749         h[e]    import            16  ...
# ...          ...        ...          ...       ...           ...  ...
# 18160   0.000002   0.287134  MGlcn161[e]    import           235  ...
# 18161   3.705479   0.114989       ins[e]    import           267  ...
# 18162   0.000044   0.562325       gal[e]    import           295  ...
# 18163   0.000017   0.562325    tchola[e]    import           295  ...
# 18164   0.000001   0.290785   MGlcn30[e]    import           306  ...
#
#            reaction_y                        name molecular_weight  C_number  \
# 0             EX_h(e)                      proton          1.00794         0
# 1             EX_h(e)                      proton          1.00794         0
# 2             EX_h(e)                      proton          1.00794         0
# 3             EX_h(e)                      proton          1.00794         0
# 4             EX_h(e)                      proton          1.00794         0
# ...               ...                         ...              ...       ...
# 18160  EX_MGlcn161(e)  mucin-type O-glycan No 161              NaN        42
# 18161       EX_ins(e)                     Inosine        268.22608        10
# 18162       EX_gal(e)                 D-Galactose        180.15588         6
# 18163    EX_tchola(e)                taurocholate        515.70300        26
# 18164   EX_MGlcn30(e)   mucin-type O-glycan No 30              NaN        40
#
#        N_number       hmdb              inchi kegg.compound pubchem.compound  \
# 0             0  HMDB01362  InChI=1S/p+1/i/hH        C00282           1038.0
# 1             0  HMDB01362  InChI=1S/p+1/i/hH        C00282           1038.0
# 2             0  HMDB01362  InChI=1S/p+1/i/hH        C00282           1038.0
# 3             0  HMDB01362  InChI=1S/p+1/i/hH        C00282           1038.0
# 4             0  HMDB01362  InChI=1S/p+1/i/hH        C00282           1038.0
# ...         ...        ...                ...           ...              ...
# 18160         3        NaN                NaN           NaN              NaN
# 18161         4  HMDB00195                NaN        C00294           6021.0
# 18162         0  HMDB00143                NaN        C00984         439357.0
# 18163         1  HMDB00036                NaN           NaN         440567.0
# 18164         2        NaN                NaN           NaN              NaN
#
#            reaction.1
# 0             EX_h(e)
# 1             EX_h(e)
# 2             EX_h(e)
# 3             EX_h(e)
# 4             EX_h(e)
# ...               ...
# 18160  EX_MGlcn161(e)
# 18161       EX_ins(e)
# 18162       EX_gal(e)
# 18163    EX_tchola(e)
# 18164   EX_MGlcn30(e)
#
# [18165 rows x 28 columns]

# %% [markdown]
# re making the graphs, with the actual metabolite names now

# %%
from plotnine import *
theme_set(theme_minimal())

Bacteroides_with_name = tests_merged_with_annotations[tests_merged_with_annotations.q < 0.05].nlargest(6, "log_mean_std")

Bacteroides_filtered_metabolites = (
    ggplot(Bacteroides_merged_with_annotations[Bacteroides_merged_with_annotations.name.isin(Bacteroides_with_name.name)])
    + aes(x="medium", y="flux")
    + theme(figure_size = (12,4))
    + geom_boxplot() 
    + geom_jitter(width=.2)
    + scale_y_log10()
    + facet_wrap("~ name")
)

Bacteroides_filtered_metabolites

Bacteroides_filtered_metabolites.save("Bacteroides_filtered_metabolites.png")
# Out:
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Saving 12 x 4 in image.
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/ggplot.py:722: PlotnineWarning: Filename: Bacteroides_filtered_metabolites.png
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
Bacteroides_filtered_metabolites
# Out:
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ggplot: (8780829744397)>

# %%
from plotnine import *
theme_set(theme_minimal())

Bacteroides_with_name = tests_merged_with_annotations[tests_merged_with_annotations.q < 0.05].nlargest(4, "log_mean_std")

Bacteroides_metabolites_with_time = (
    ggplot(Bacteroides_merged_with_annotations[Bacteroides_merged_with_annotations.name.isin(Bacteroides_with_name.name)])
    + aes(x="medium", y="flux", color = "time_point")
    + theme(figure_size = (12,4))
    + geom_boxplot() 
    + geom_jitter(width=.2)
    + scale_y_log10()
    + facet_wrap("~ name")
)

Bacteroides_metabolites_with_time
# Out:
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# /users/sswegle/miniconda3/envs/micom/lib/python3.8/site-packages/plotnine/utils.py:371: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <ggplot: (8780779339713)>
